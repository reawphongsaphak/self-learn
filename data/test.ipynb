# %%
import matplotlib.pyplot as plt
import math

# %%
num = [i for i in range (-50,50)]
ls = []
def cal(x):
    return 1*((math.e)**((-1*(x**2))/2))/((2*math.pi)**0.5)
for x in num:
    ls.append(cal(x))

# %%
plt.plot(num,ls)
