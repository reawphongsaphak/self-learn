# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"/Users/phongsaphak/Documents/data_set/disease/blood_samples_dataset_test.csv")
df.head()
# Out:
#     Glucose  Cholesterol  Hemoglobin  Platelets  White Blood Cells  \
# 0  0.001827     0.033693    0.114755   0.997927           0.562604
# 1  0.436679     0.972653    0.084998   0.180909           0.675736
# 2  0.545697     0.324815    0.584467   0.475748           0.558596
# 3  0.172994     0.050351    0.736000   0.782022           0.069435
# 4  0.758534     0.739968    0.597868   0.772683           0.875720
#
#    Red Blood Cells  Hematocrit  Mean Corpuscular Volume  \
# 0         0.866499    0.578042                 0.914615
# 1         0.563889    0.798382                 0.670361
# 2         0.661007    0.934056                 0.381782
# 3         0.085219    0.032907                 0.460619
# 4         0.860265    0.486189                 0.486686
#
#    Mean Corpuscular Hemoglobin  Mean Corpuscular Hemoglobin Concentration  \
# 0                     0.026864                                   0.038641
# ...

# %%
df2 = pd.read_csv(r"/Users/phongsaphak/Documents/data_set/disease/Blood_samples_dataset_balanced_2(f).csv")
df2.head()
# Out:
#     Glucose  Cholesterol  Hemoglobin  Platelets  White Blood Cells  \
# 0  0.739597     0.650198    0.713631   0.868491           0.687433
# 1  0.121786     0.023058    0.944893   0.905372           0.507711
# 2  0.452539     0.116135    0.544560   0.400640           0.294538
# 3  0.136609     0.015605    0.419957   0.191487           0.081168
# 4  0.176737     0.752220    0.971779   0.785286           0.443880
#
#    Red Blood Cells  Hematocrit  Mean Corpuscular Volume  \
# 0         0.529895    0.290006                 0.631045
# 1         0.403033    0.164216                 0.307553
# 2         0.382021    0.625267                 0.295122
# 3         0.166214    0.073293                 0.668719
# 4         0.439851    0.894991                 0.442159
#
#    Mean Corpuscular Hemoglobin  Mean Corpuscular Hemoglobin Concentration  \
# 0                     0.001328                                   0.795829
# ...

# %%
disease_ls = df["Disease"].unique()
disease_ls
# Out:
# array(['Thalasse', 'Diabetes', 'Heart Di', 'Anemia', 'Thromboc',
#        'Healthy'], dtype=object)

# %%
df.isna().sum()
# Out:
# Glucose                                      0
# Cholesterol                                  0
# Hemoglobin                                   0
# Platelets                                    0
# White Blood Cells                            0
# Red Blood Cells                              0
# Hematocrit                                   0
# Mean Corpuscular Volume                      0
# Mean Corpuscular Hemoglobin                  0
# Mean Corpuscular Hemoglobin Concentration    0
# Insulin                                      0
# BMI                                          0
# Systolic Blood Pressure                      0
# Diastolic Blood Pressure                     0
# Triglycerides                                0
# HbA1c                                        0
# LDL Cholesterol                              0
# HDL Cholesterol                              0
# ALT                                          0
# AST                                          0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(disease_ls)
df["Disease"] = le.fit_transform(df["Disease"])
df.head()
# Out:
#     Glucose  Cholesterol  Hemoglobin  Platelets  White Blood Cells  \
# 0  0.001827     0.033693    0.114755   0.997927           0.562604
# 1  0.436679     0.972653    0.084998   0.180909           0.675736
# 2  0.545697     0.324815    0.584467   0.475748           0.558596
# 3  0.172994     0.050351    0.736000   0.782022           0.069435
# 4  0.758534     0.739968    0.597868   0.772683           0.875720
#
#    Red Blood Cells  Hematocrit  Mean Corpuscular Volume  \
# 0         0.866499    0.578042                 0.914615
# 1         0.563889    0.798382                 0.670361
# 2         0.661007    0.934056                 0.381782
# 3         0.085219    0.032907                 0.460619
# 4         0.860265    0.486189                 0.486686
#
#    Mean Corpuscular Hemoglobin  Mean Corpuscular Hemoglobin Concentration  \
# 0                     0.026864                                   0.038641
# ...

# %%
x = df.drop(["Disease"], axis=1)
y = df["Disease"]

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8)

# %%
from sklearn.neighbors import KNeighborsClassifier
kn = KNeighborsClassifier()
kn.fit(x_train, y_train)
y_pred = kn.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)

print(classification_report(y_test,y_pred))
print(accuracy)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.28      0.54      0.37        13
#            1       0.74      0.71      0.72        65
#            2       0.00      0.00      0.00         1
#            3       0.33      0.43      0.38         7
#            4       0.00      0.00      0.00         7
#            5       0.00      0.00      0.00         5
#
#     accuracy                           0.57        98
#    macro avg       0.23      0.28      0.24        98
# weighted avg       0.55      0.57      0.56        98
#
# 0.5714285714285714
# /Users/phongsaphak/python_data/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(x_train,y_train)
y_pred = rfc.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)

print(classification_report(y_test,y_pred))
print(accuracy)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.62      0.70        13
#            1       0.83      1.00      0.91        65
#            2       0.00      0.00      0.00         1
#            3       0.75      0.43      0.55         7
#            4       1.00      0.71      0.83         7
#            5       1.00      0.20      0.33         5
#
#     accuracy                           0.84        98
#    macro avg       0.73      0.49      0.55        98
# weighted avg       0.83      0.84      0.81        98
#
# 0.8367346938775511
# /Users/phongsaphak/python_data/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
df2["Disease"] = le.fit_transform(df2["Disease"])
df2
# Out:
#        Glucose  Cholesterol  Hemoglobin  Platelets  White Blood Cells  \
# 0     0.739597     0.650198    0.713631   0.868491           0.687433
# 1     0.121786     0.023058    0.944893   0.905372           0.507711
# 2     0.452539     0.116135    0.544560   0.400640           0.294538
# 3     0.136609     0.015605    0.419957   0.191487           0.081168
# 4     0.176737     0.752220    0.971779   0.785286           0.443880
# ...        ...          ...         ...        ...                ...
# 2346  0.012956     0.336925    0.451218   0.175006           0.734664
# 2347  0.407101     0.124738    0.983306   0.663867           0.361113
# 2348  0.344356     0.783918    0.582171   0.996841           0.065363
# 2349  0.351722     0.014278    0.898615   0.167550           0.727148
# 2350  0.032726     0.053596    0.102633   0.221356           0.153956
#
#       Red Blood Cells  Hematocrit  Mean Corpuscular Volume  \
# 0            0.529895    0.290006                 0.631045
# ...

# %%
goal = df2["Disease"]
data = df2.drop(["Disease"], axis=1)
pred = rfc.predict(data)
accuracy = accuracy_score(pred,goal)
print(accuracy)
# Out:
# 0.43853679285410463
